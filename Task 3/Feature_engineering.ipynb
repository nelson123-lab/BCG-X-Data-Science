# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:/Users/NELSON JOSEPH/Desktop/Backup/Internships/BCGX_datascience/Task 2/client_data_cleaned.csv')
data.head(5)
# Out:
#                                  id  channel_sales  cons_12m  cons_gas_12m  \
# 0  24011ae4ebbe3035111d65fa7c15bc57              3         0         54946
# 1  d29c2c54acc38ff3c0614d0a653813dd              3      4660             0
# 2  764c75f661154dac3a6c254cd082ea7d              3       544             0
# 3  bba03439a292a1e166f80264c16191cb              4      1584             0
# 4  149d57cf92fc41cf94415803a877cb4b              4      4425             0
#
#    cons_last_month  date_modif_prod  forecast_cons_12m  forecast_cons_year  \
# 0                0                1               0.00                   0
# 1                0                0             189.95                   0
# 2                0                0              47.96                   0
# 3                0                0             240.04                   0
# 4              526                0             445.75                 526
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'channel_sales', 'cons_12m', 'cons_gas_12m', 'cons_last_month',
#        'date_modif_prod', 'forecast_cons_12m', 'forecast_cons_year',
#        'forecast_discount_energy', 'forecast_meter_rent_12m',
#        'forecast_price_energy_off_peak', 'forecast_price_energy_peak',
#        'forecast_price_pow_off_peak', 'has_gas', 'imp_cons',
#        'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act',
#        'net_margin', 'num_years_antig', 'origin_up', 'pow_max', 'churn',
#        'c_duration'],
#       dtype='object')
